# %%
with open('../data_bak/validation_combined.txt', 'rt') as f:
    lines = f.readlines()
    sample = [line for line in lines if 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb' in line]
    print(sample)
# Out:
# ['nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 1 23 4\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 130 35 10\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 261 29 19\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 304 38 126\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 347 25 863\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 398 20 3\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 408 33 23\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 425 139 782\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 572 43 1061\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 614 12 907\n', 'nusar-2021_action_both_9073-a18_9073_user_id_2021-02-11_140513/C10404_rgb 652 16 21\n', 'nusar-2021_act
# ...

# %%
with open('../data/train_combined.txt', 'wt') as f:
    f.writelines(sample)
